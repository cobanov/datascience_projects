# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Iris.csv")

# %%
sample_data = data.sample(20)

# %%
for _ in range(10):
    sample_data.iloc[np.random.randint(1,20), np.random.randint(1,5)] = np.nan

# %%
all_data = pd.concat([data, sample_data], axis=0)

# %%
selected_columns = data.columns[1:-1]

# %%
all_data.sort_values(by="Species", inplace=True)

# %%
all_data.reset_index(drop=True, inplace=True)
all_data.drop("Id", axis=1, inplace=True)

# %%
all_data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            5.2           4.1            1.5           0.1  Iris-setosa
# 2            5.5           4.2            1.4           0.2  Iris-setosa
# 3            4.9           3.1            1.5           0.1  Iris-setosa
# 4            5.0           3.2            1.2           0.2  Iris-setosa

# %%
all_data.reset_index(inplace=True)

# %%
all_data
# Out:
#      index  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0        0            5.1           3.5            1.4           0.2
# 1        1            5.2           4.1            1.5           0.1
# 2        2            5.5           4.2            1.4           0.2
# 3        3            4.9           3.1            1.5           0.1
# 4        4            5.0           3.2            1.2           0.2
# ..     ...            ...           ...            ...           ...
# 165    165            6.9           3.2            5.7           2.3
# 166    166            6.0           2.2            5.0           1.5
# 167    167            7.7           2.6            6.9           2.3
# 168    168            6.7           3.3            5.7           2.1
# 169    169            6.3           3.3            6.0           2.5
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
all_data.rename({"index":"Id"}, inplace=True,axis=1)

# %%
all_data.to_csv("data_with_nans2.csv")

# %%
all_data.to_csv("iris_with_nans.csv")

# %%
for columns in selected_columns:
    fig = sns.scatterplot(y=columns, x="Id", hue="Species", data=data)
    plt.show()
